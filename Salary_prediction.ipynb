# %% [markdown]
# <a href="https://colab.research.google.com/github/abhavanasaraswathi/Salary-prediction-/blob/main/Salary_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import joblib

# %%
df= pd.read_csv("/content/salary_prediction_dataset (3).csv")

# %%
df.head()
# Out:
#    Experience  Test_Score  Salary
# 0           1          55   28000
# 1           2          60   32000
# 2           3          65   36000
# 3           4          70   41000
# 4           5          72   45000

# %%
df.tail()
# Out:
#     Experience  Test_Score  Salary
# 15          16          89   82000
# 16          17          94   90000
# 17          18          91   88000
# 18          19          96   96000
# 19          20          98  102000

# %%
print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# Experience    0
# Test_Score    0
# Salary        0
# dtype: int64

# %%
df = df.dropna()

# %%
X = df[['Experience', 'Test_Score']]
y = df['Salary']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=34
)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

# %%
print("\nModel Evaluation:")
print("RMSE:", rmse)
print("R2 Score:", r2)
# Out:
# Model Evaluation:
# RMSE: 3326.271461051799
# R2 Score: 0.9854944846507929

# %%
print("\nModel Coefficients:")
# Out:
# Model Coefficients:

# %%
for feature, coefficient in zip(X.columns, model.coef_):
    print(feature, ":", coefficient)

print("Intercept:", model.intercept_)
# Out:
# Experience : 2724.165460712056
# Test_Score : 587.2363259704665
# Intercept: -11854.42912539313

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load dataset
df = pd.read_csv("/content/salary_prediction_dataset (3).csv")

# Input and output
X = df[["Experience", "Test_Score"]]
y = df["Salary"]

# Train model
model = LinearRegression()
model.fit(X, y)

# Predictions
y_pred = model.predict(X)

# Graph: Actual vs Predicted Salary
plt.scatter(y, y_pred)

plt.xlabel("Actual Salary")
plt.ylabel("Predicted Salary")
plt.title("Actual Salary vs Predicted Salary")

plt.show()
